# %%
data = [("iPhone", 999), ("Samsung", 799), ("MacBook", 1299)]
df = spark.createDataFrame(data, ["product", "price"])
df.show()
# Out:
# +-------+-----+
# |product|price|
# +-------+-----+
# | iPhone|  999|
# |Samsung|  799|
# |MacBook| 1299|
# +-------+-----+

# %%
df.filter(df.price > 1000).show()
# Out:
# +-------+-----+
# |product|price|
# +-------+-----+
# |MacBook| 1299|
# +-------+-----+

# %%
df.printSchema()
df.explain()
# Out:
# root
#  |-- product: string (nullable = true)
#  |-- price: long (nullable = true)
#
# == Physical Plan ==
# LocalTableScan [product#13337, price#13338L]
#
#
# == Photon Explanation ==
# Photon does not fully support the query because:
# 		Unsupported node: LocalTableScan [product#13337, price#13338L].
#
# Reference node:
# 	LocalTableScan [product#13337, price#13338L]
